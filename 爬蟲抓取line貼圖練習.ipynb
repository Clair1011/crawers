# %%
import requests,os,json
from bs4 import BeautifulSoup

url = 'https://store.line.me/stickershop/product/17110/zh-Hant'
html = requests.get(url)
soup = BeautifulSoup(html.text,'html.parser')

#建立目錄儲存圖片
images_dir = 'line_image/'
if not os.path.exists(images_dir):
    os.mkdir(images_dir)
#下載貼圖
datas = soup.find_all('li',{'class':'mdCMN09Li FnStickerPreviewItem'})
for data in datas:
    #將字串資料轉換為字典
    imginfo = json.loads(data.get('data-preview'))
    id=imginfo['id']
    imgfile = requests.get(imginfo['staticUrl'])#載入圖片
    
    full_path = os.path.join(images_dir,id) #儲存的路徑和主檔名
    #儲存圖片
    with open(full_path + '.png','wb') as f:
        f.write(imgfile.content)
    print(full_path + '.png') #顯示儲存的路徑和檔名
# Out:
# line_image/302514174.png
# line_image/302514175.png
# line_image/302514176.png
# line_image/302514177.png
# line_image/302514178.png
# line_image/302514179.png
# line_image/302514180.png
# line_image/302514181.png
# line_image/302514182.png
# line_image/302514183.png
# line_image/302514184.png
# line_image/302514185.png
# line_image/302514186.png
# line_image/302514187.png
# line_image/302514188.png
# line_image/302514189.png
# line_image/302514190.png
# line_image/302514191.png
# line_image/302514192.png
# line_image/302514193.png
# line_image/302514194.png
# line_image/302514195.png
# line_image/302514196.png
# line_image/302514197.png

# %%
import requests,os,json
from bs4 import BeautifulSoup
url = 'https://store.line.me/stickershop/product/9188/zh-Hant'
html = requests.get(url)
soup = BeautifulSoup(html.text,'html.parser')

img = 'line1_image/'
if not os.path.exists(img):
    os.mkdir(img)
    
datas = soup.find_all('li',{'class':'mdCMN09Li FnStickerPreviewItem'})
for data in datas:
    
    imga=json.loads(data.get('data-preview'))
    id = imga['id']
    r = requests.get(imga['staticUrl'])#下載圖片
    full_path =img + id +'.png'
    
    with open (full_path ,'wb') as p:
        p.write(r.content)
        print(full_path)
# Out:
# line1_image/18978752.png
# line1_image/18978753.png
# line1_image/18978754.png
# line1_image/18978755.png
# line1_image/18978756.png
# line1_image/18978757.png
# line1_image/18978758.png
# line1_image/18978759.png
# line1_image/18978760.png
# line1_image/18978761.png
# line1_image/18978762.png
# line1_image/18978763.png
# line1_image/18978764.png
# line1_image/18978765.png
# line1_image/18978766.png
# line1_image/18978767.png
# line1_image/18978768.png
# line1_image/18978769.png
# line1_image/18978770.png
# line1_image/18978771.png
# line1_image/18978772.png
# line1_image/18978773.png
# line1_image/18978774.png
# line1_image/18978775.png
# line1_image/18978776.png
# line1_image/18978777.png
# line1_image/18978778.png
# line1_image/18978779.png
# line1_image/18978780.png
# line1_image/18978781.png
# line1_image/18978782.png
# line1_image/18978783.png
# line1_image/18978784.png
# line1_image/18978785.png
# line1_image/18978786.png
# line1_image/18978787.png
# line1_image/18978788.png
# ...

# %%
url= 'https://store.line.me/stickershop/product/19352/zh-Hant'
html = requests.get(url)
soup = BeautifulSoup(html.text,'html.parser')

#建立目錄
image_dir = 'line2_image/'
if not os.path.exists(image_dir):
    os.mkdir(image_dir)
     #解析圖片
datas = soup.find_all('li',{'class':'mdCMN09Li FnStickerPreviewItem'})
for data in datas:
    jimage = json.loads(data.get('data-preview'))
    id = jimage['id']
    pimg = requests.get(jimage['staticUrl'])
    path_all = image_dir + id +'.png'
    
    with open(path_all,'wb') as f:
        f.write(pimg.content)
        print(path_all)
# Out:
# line2_image/364763046.png
# line2_image/364763047.png
# line2_image/364763048.png
# line2_image/364763049.png
# line2_image/364763050.png
# line2_image/364763051.png
# line2_image/364763052.png
# line2_image/364763053.png
# line2_image/364763054.png
# line2_image/364763055.png
# line2_image/364763056.png
# line2_image/364763057.png
# line2_image/364763058.png
# line2_image/364763059.png
# line2_image/364763060.png
# line2_image/364763061.png
# line2_image/364763062.png
# line2_image/364763063.png
# line2_image/364763064.png
# line2_image/364763065.png
# line2_image/364763066.png
# line2_image/364763067.png
# line2_image/364763068.png
# line2_image/364763069.png
# line2_image/364763070.png
# line2_image/364763071.png
# line2_image/364763072.png
# line2_image/364763073.png
# line2_image/364763074.png
# line2_image/364763075.png
# line2_image/364763076.png
# line2_image/364763077.png
# line2_image/364763078.png
# line2_image/364763079.png
# line2_image/364763080.png
# ...

# %%
import requests,os,json
from bs4 import BeautifulSoup
url = 'https://store.line.me/stickershop/product/19347/zh-Hant'
html = requests.get(url)
soup = BeautifulSoup(html.text,'html.parser')

imgg = 'line3_image/'
if not os.path.exists(imgg):
    os.mkdir(imgg)
    
datas = soup.find_all('li',{'class':'mdCMN09Li FnStickerPreviewItem'})
for data in datas:
    jimagg = json.loads(data.get('data-preview'))
    id = jimagg['id']
    dimagg = requests.get(jimagg['staticUrl'])
    
    pathfull = imgg + id + '.png' 
    
    with open(pathfull,'wb') as f:
        f.write(dimagg.content)
        print(pathfull)
# Out:
# line3_image/365565158.png
# line3_image/365565159.png
# line3_image/365565160.png
# line3_image/365565161.png
# line3_image/365565162.png
# line3_image/365565163.png
# line3_image/365565164.png
# line3_image/365565165.png
# line3_image/365565166.png
# line3_image/365565167.png
# line3_image/365565168.png
# line3_image/365565169.png
# line3_image/365565170.png
# line3_image/365565171.png
# line3_image/365565172.png
# line3_image/365565173.png
# line3_image/365565174.png
# line3_image/365565175.png
# line3_image/365565176.png
# line3_image/365565177.png
# line3_image/365565178.png
# line3_image/365565179.png
# line3_image/365565180.png
# line3_image/365565181.png
